# %% [markdown]
# #Setup Python bpmn-client

# %%
# !pip install -U bpmnclient
# !pip show bpmnclient
# Out:
# Requirement already satisfied: bpmnclient in c:\python312\lib\site-packages (1.0.4)
# Name: bpmnClient
# Version: 1.0.4
# Summary: bpmnServer python client
# Home-page:
# Author:
# Author-email: ralph hanna <ralphhanna@hotmail.com>
# License:
# Location: C:\Python312\Lib\site-packages
# Requires:
# Required-by:

# %%
from collections import defaultdict
from IPython.display import HTML , IFrame
import ipywidgets
from pprint import pprint

# %%
def displayTable(data,cols):
  html = "<table>"
  for col in cols:
    html = f"{html}<th style='text-align:center;'>{col}</th>"
  for row in data:
    html = f"{html}<tr>"
    for col in cols:
      html = f"{html}<td style='text-align:left;'>{row[col]}</td>"
    html = f"{html}</tr>"
  html = f"{html}</table>"

  return display(HTML(html))

def displayItems(res):
  return displayTable(res['items'],['seq','elementId', 'status'])

def displayDiagram(name):
  url = f"https://bpmn.omniworkflow.com/model/getSVg/{name}"

  return HTML(f"<img src='{url}' width='100%' height='100%'/>")

def displayPage(url):
  display(IFrame(url,"100%","100%"))
  #return HTML(f"<iframe src='{url}' width='100%' height='100%'></iframe>")

def describeModel(name):
    
  model=bpmn.model.loadModel(name)
  display(HTML('<h2>Elements</h2>'))

  els=[]
  for el in model.res['elements']:
      el["property"]=''
      el["value"]=''
      els.append(el)
      for des in el["description"]:
          el1={"id":'',"type":'',"property":des[0],"value":des[1]}
          els.append(el1)
          
  displayTable(els,['id','type','property','value'])

  display(HTML('<h2>Sequence Flows</h2>'))

  els=[]
  for el in model.res['flows']:
      el["property"]=''
      el["value"]=''
      els.append(el)
      for des in el["description"]:
          el1={"id":'',"type":'',"property":des[0],"value":des[1]}
          els.append(el1)
    
  displayTable(els,['id','type','property','value'])

# %% [markdown]
# We Start by installing Python Package for `bpmnclient

# %% [markdown]
# Let us import required classes
# - `bpmn2.BPMNClient2' is version 2.0 API
# - `Response` is a utility to help display response object

# %%
from bpmnClient import bpmn2
Response =bpmn2.Response

#help(bpmn2)

#cl = bpmn2.BPMNClient2('bpmn.omniworkflow.com','443','12345')
bpmn = bpmn2.BPMNClient2('localhost','3000','12345')

# %% [markdown]
# Define a `user` object that we will be using throughout this exercise

# %%
user = {"userName":"John Kennedy", "userGroups":["Admin"]}

# %% [markdown]
# List the Models available to us:

# %% [markdown]
# # List Models

# %%
list=bpmn.model.listModels()
displayTable(list,['name'])
# Out:
# <table><th style='text-align:center;'>name</th><tr><td style='text-align:left;'>ad hoc</td></tr><tr><td style='text-align:left;'>boundary-event</td></tr><tr><td style='text-align:left;'>bpmn-server-arch</td></tr><tr><td style='text-align:left;'>Buy Used Car with Lanes</td></tr><tr><td style='text-align:left;'>Buy Used Car</td></tr><tr><td style='text-align:left;'>CallTask</td></tr><tr><td style='text-align:left;'>Cancel Application</td></tr><tr><td style='text-align:left;'>Cash Request</td></tr><tr><td style='text-align:left;'>Error events</td></tr><tr><td style='text-align:left;'>Event Based Gateway</td></tr><tr><td style='text-align:left;'>Hungry</td></tr><tr><td style='text-align:left;'>Invoice</td></tr><tr><td style='text-align:left;'>Leave Application</td></tr><tr><td style='text-align:left;'>loop</td></tr><tr><td style='text-align:left;'>messageFlow</td></tr><tr><td style='text-align:left;'>MsgCatch</td></tr><tr><td style='text-align:left;'>msgThrow</td></tr><tr><td style='text-align:left;'>multiStart</td></tr><tr><td style='text-align:left;'>pizza store example</td></tr><tr><td style='text-align:left;'>ReceiveTask</td></tr><tr><td style='text-align:left;'>Restart</td></tr><tr><td style='text-align:left;'>scripts and services</td></tr><tr><td style='text-align:left;'>sendTask</td></tr><tr><td style='text-align:left;'>serviceTask</td></tr><tr><td style='text-align:left;'>SubProcess</td></tr><tr><td style='text-align:left;'>timer-sample</td></tr><tr><td style='text-align:left;'>Trans</td></tr></table>

# %% [markdown]
# # Describe **Buy Used Car** model

# %%
displayDiagram('Buy Used Car')
# Out:
# <img src='https://bpmn.omniworkflow.com/model/getSVg/Buy Used Car' width='100%' height='100%'/>

# %%
describeModel('Buy Used Car')
# Out:
# <h2>Elements</h2>
# <table><th style='text-align:center;'>id</th><th style='text-align:center;'>type</th><th style='text-align:center;'>property</th><th style='text-align:center;'>value</th><tr><td style='text-align:left;'>task_clean</td><td style='text-align:left;'>bpmn:UserTask</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>gateway_2</td><td style='text-align:left;'>bpmn:ParallelGateway</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>task_repair</td><td style='text-align:left;'>bpmn:UserTask</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>task_Drive</td><td style='text-align:left;'>bpmn:UserTask</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>candidateUsers</td><td style='text-align:left;'>$data.starterUserId</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>dueDate</td><td style='text-align:left;'>P10D</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>followUpDate</td><td style='text-align:left;'>P5D</td></tr><tr><td style='text-align:left;'>gateway_1</td><td style='text-align:left;'>bpmn:InclusiveGateway</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>Event_19ebav7</td><td style='text-align:left;'>bpmn:EndEvent</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>task_Buy</td><td style='text-align:left;'>bpmn:UserTask</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>script on start </td><td style='text-align:left;'>var date=new Date();
# date.setDate(date.getDate()+5);
# this.dueDate=date.toISOString();</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>script on validate </td><td style='text-align:left;'>item.vars=item.input;</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>assignee</td><td style='text-align:left;'>$(this.data.starterUserId)</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>candidateGroups</td><td style='text-align:left;'>Employee,Manager</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>candidateUsers</td><td style='text-align:left;'>User1,User2</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>dueDate</td><td style='text-align:left;'>$this.dueDate</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>followUpDate</td><td style='text-align:left;'>2023-10-31</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>priority</td><td style='text-align:left;'>5</td></tr><tr><td style='text-align:left;'>StartEvent_158yep3</td><td style='text-align:left;'>bpmn:StartEvent</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>Initiator</td><td style='text-align:left;'>starterUserId</td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>script on end </td><td style='text-align:left;'>data.startDate=this.startedAt;</td></tr></table>
# <h2>Sequence Flows</h2>
# <table><th style='text-align:center;'>id</th><th style='text-align:center;'>type</th><th style='text-align:center;'>property</th><th style='text-align:center;'>value</th><tr><td style='text-align:left;'>flow_start_buy</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>flow_buy_gw</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>flow_gw1_clean</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>condition: </td><td style='text-align:left;'>$(item.data.needsCleaning=="Yes")</td></tr><tr><td style='text-align:left;'>flow_clean_gw2</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>flow_repair_gw2</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>flow_gw1_gw2</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>flow_gw2_drive</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'>flow_gw1_repair</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr><tr><td style='text-align:left;'></td><td style='text-align:left;'></td><td style='text-align:left;'>condition: </td><td style='text-align:left;'>$(item.data.needsRepairs=="Yes")</td></tr><tr><td style='text-align:left;'>flow_drive_end</td><td style='text-align:left;'>bpmn:SequenceFlow</td><td style='text-align:left;'></td><td style='text-align:left;'></td></tr></table>

# %% [markdown]
# # Run "Buy Used Car" Model

# %% [markdown]
# Clear out any previous cases for this exercise

# %%
caseId = "7002" # @param {type:"string"}
res=bpmn.data.delete_instances({"data.caseId":caseId},user)
print('Instances Deleted:',res["result"]["deletedCount"])
# Out:
# Instances Deleted: 4

# %%
res=bpmn.engine.start("Buy Used Car",{"caseId":caseId},user)
displayItems(res)
# Out:
# <table><th style='text-align:center;'>seq</th><th style='text-align:center;'>elementId</th><th style='text-align:center;'>status</th><tr><td style='text-align:left;'>0</td><td style='text-align:left;'>StartEvent_158yep3</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>1</td><td style='text-align:left;'>flow_start_buy</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>2</td><td style='text-align:left;'>task_Buy</td><td style='text-align:left;'>wait</td></tr></table>

# %%
res=bpmn.engine.invoke({"data.caseId":caseId,"items.elementId":"task_Buy"},{"needsRepairs":"Yes"},user)
displayItems(res)
# Out:
# <table><th style='text-align:center;'>seq</th><th style='text-align:center;'>elementId</th><th style='text-align:center;'>status</th><tr><td style='text-align:left;'>0</td><td style='text-align:left;'>StartEvent_158yep3</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>1</td><td style='text-align:left;'>flow_start_buy</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>2</td><td style='text-align:left;'>task_Buy</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>3</td><td style='text-align:left;'>flow_buy_gw</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>4</td><td style='text-align:left;'>gateway_1</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>6</td><td style='text-align:left;'>flow_gw1_repair</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>7</td><td style='text-align:left;'>task_repair</td><td style='text-align:left;'>wait</td></tr></table>

# %%
res=bpmn.engine.invoke({"data.caseId":caseId,"items.elementId":"task_repair"},{},user)
res=bpmn.engine.invoke({"data.caseId":caseId,"items.elementId":"task_Drive"},{},user)
displayItems(res)
# Out:
# <table><th style='text-align:center;'>seq</th><th style='text-align:center;'>elementId</th><th style='text-align:center;'>status</th><tr><td style='text-align:left;'>0</td><td style='text-align:left;'>StartEvent_158yep3</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>1</td><td style='text-align:left;'>flow_start_buy</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>2</td><td style='text-align:left;'>task_Buy</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>3</td><td style='text-align:left;'>flow_buy_gw</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>4</td><td style='text-align:left;'>gateway_1</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>6</td><td style='text-align:left;'>flow_gw1_repair</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>7</td><td style='text-align:left;'>task_repair</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>7</td><td style='text-align:left;'>flow_repair_gw2</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>8</td><td style='text-align:left;'>gateway_2</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>9</td><td style='text-align:left;'>flow_gw2_drive</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'>10</td><td style='text-align:left;'>task_Drive</td><td style='text-align:left;'>end</td></tr><tr><td style='text-align:left;'
z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'f0886677-ce87-4a2a-b622-62ccac115770',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': '3db4081e-89cf-4ebc-ad7a-867da4a46716',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': None,
#   'startedAt': '2024-06-13T03:38:36.300Z',
#   'endedAt': '2024-06-13T03:38:36.301Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '886db47e-5a87-4f40-af34-06208598f79e',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None,
#    'startDate': None,
#    'model': 'Thunderbird',
#    'needsRepairs': False,
#    'needsCleaning': False},
#   'instanceVersion': 0},
#  {'id': '9091f767-6e4b-4ca4-ae5f-8caea498889e',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': None,
#   'startedAt': '2024-06-13T19:22:35.699Z',
#   'endedAt': '2024-06-13T19:22:35.707Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'b086980c-2273-4cce-83c1-ec67989c8b6a',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 393, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': '8fea3981-bf61-4276-a8d8-5d947d6bbd37',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': None,
#   'startedAt': '2024-06-13T19:24:51.840Z',
#   'endedAt': '2024-06-13T19:24:51.853Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'eb876029-ccff-4186-978c-54a2a7b5ec52',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 2169, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': 'ca8b246f-f325-47f1-bdc4-27ec58c69afb',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': None,
#   'startedAt': '2024-06-13T19:33:33.737Z',
#   'endedAt': '2024-06-13T19:33:33.748Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'c21e3aa3-92bb-4634-bd45-d1af91e3520b',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 3907, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': '00fe6aae-1c3a-4292-bf7f-e32002acc0e6',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': None,
#   'startedAt': '2024-06-13T19:37:45.160Z',
#   'endedAt': '2024-06-13T19:37:45.172Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'a812b3b6-30ec-414e-9d6f-8292338daf4d',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 7583, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': '6fb85235-6935-4009-85d0-b1c9b4c06746',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': 'John',
#   'startedAt': '2024-06-13T19:39:48.103Z',
#   'endedAt': '2024-06-13T19:39:48.114Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '3b15cb73-427b-472b-91cd-b1455468afaf',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 9311, 'starterUserId': 'John', 'startDate': None},
#   'instanceVersion': 0},
#  {'id': 'aa677103-f4ee-4a5b-93a7-5aaec3e3764a',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': None,
#   'startedAt': '2024-06-14T04:58:22.725Z',
#   'endedAt': '2024-06-14T04:58:22.730Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '53305b6a-76ed-4341-826d-3a7ae312e1d9',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': '98dc5deb-565b-412d-89b9-f0e3e3af9dd0',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': 'system',
#   'startedAt': '2024-06-15T20:37:59.410Z',
#   'endedAt': '2024-06-15T20:37:59.420Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '05e798ba-9e0f-45f4-837b-1b57dc66803a',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 9148, 'starterUserId': 'system', 'startDate': None},
#   'instanceVersion': 0},
#  {'id': 'a5335818-4eb6-46ed-8431-fd5cf55547fd',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': 'system',
#   'startedAt': '2024-06-15T20:39:43.293Z',
#   'endedAt': '2024-06-15T20:39:43.303Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '15560aae-815b-4314-b5d5-2100cf4702cf',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 9149,
#    'starterUserId': 'system',
#    'startDate': '2024-06-15T20:39:43.293Z'},
#   'instanceVersion': 0},
#  {'id': '5c2707f9-22bc-4734-846a-b7e73dcca1ed',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': 'john',
#   'startedAt': '2024-06-19T17:44:32.183Z',
#   'endedAt': '2024-06-19T17:44:32.215Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '710fc6b3-55c4-4990-8bd4-65e537445cc5',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 3030,
#    'claim': 'abc',
#    'starterUserId': 'john',
#    'startDate': '2024-06-19T17:44:32.183Z'},
#   'instanceVersion': 0},
#  {'id': '34879447-4730-4fb8-8640-757f644549d0',
#   'seq': 0,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'StartEvent_158yep3',
#   'name': None,
#   'status': 'end',
#   'userName': 'John Kennedy',
#   'startedAt': '2024-06-21T04:33:53.232Z',
#   'endedAt': '2024-06-21T04:33:53.244Z',
#   'type': 'bpmn:StartEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'bfce03c4-2c3d-4887-80a6-158fb8a1e186',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId
 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': 'e1c90f45-7e2c-4319-aef4-ed653526c2e5',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'end',
#   'userName': None,
#   'startedAt': '2024-05-25T04:20:14.842Z',
#   'endedAt': '2024-05-25T04:20:14.863Z',
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '92059e0b-9fd9-44a9-9112-97eb84069a12',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 5002, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': '242256a6-6355-49e6-a987-0a42bf7bb2ce',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'Event_19ebav7',
#   'name': None,
#   'status': 'end',
#   'userName': None,
#   'startedAt': '2024-05-25T04:20:14.863Z',
#   'endedAt': '2024-05-25T04:20:14.864Z',
#   'type': 'bpmn:EndEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '92059e0b-9fd9-44a9-9112-97eb84069a12',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 5002, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': '3ef2e4a6-18f8-4114-b5a4-46a250d6a89e',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-05-25T04:20:14.811Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '3306c35b-9b06-4cf8-bd78-a7788c864f2b',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 5003, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': 'fd73d492-a329-4764-b06a-75f6a73675b7',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': 'system',
#   'startedAt': '2024-06-12T04:44:02.212Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'a3143d86-086a-4146-ae29-b7ce29cd0eb3',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': 'system',
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 7201,
#    'starterUserId': 'system',
#    'startDate': None,
#    'needsRepairs': '',
#    'needsCleaning': ''},
#   'instanceVersion': 0},
#  {'id': '072f6eac-c331-4df9-b331-468ddd3dd280',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': 'system',
#   'startedAt': '2024-06-12T04:59:49.801Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '11f07df2-4038-45bf-9409-6702c7a6e300',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': 'system',
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 5385,
#    'starterUserId': 'system',
#    'startDate': None,
#    'dummy': '1234'},
#   'instanceVersion': 0},
#  {'id': '5a8a5d26-eaf1-492f-944f-de04894bad60',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-06-12T23:23:05.912Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '8a59acc9-ef34-476a-a1f0-fd47b568a419',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None, 'startDate': None, 'dummy': '1234'},
#   'instanceVersion': 0},
#  {'id': '0aa0555a-b6d9-4f6c-80d3-d440f5dca23a',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-06-12T23:24:45.558Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '70afcfa6-ea1e-4384-a0db-dac3acad1065',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None, 'startDate': None, 'dummy': '1234'},
#   'instanceVersion': 0},
#  {'id': '897977be-3cb0-4b1a-9883-ee7cbf3d9fbd',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-06-12T23:26:27.525Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '6e98b6e0-41a0-46e0-82c9-185b2b375a3e',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None, 'startDate': None, 'dummy': '1234'},
#   'instanceVersion': 0},
#  {'id': 'fe0dedec-6f0a-45ee-b501-8c8c007f286a',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-06-12T23:29:12.810Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'd43878ec-1cda-4ed9-bb12-d16a0d4ca4fc',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None,
#    'startDate': None,
#    'model': 'Thunderbird',
#    'needsRepairs': False,
#    'needsCleaning': False},
#   'instanceVersion': 0},
#  {'id': '79bfeec2-2acb-4c30-9327-4bb48e3a5c26',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-06-12T23:32:35.301Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'c5229b22-a1e1-4d48-a3ee-e368aa0d1684',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None,
#    'startDate': None,
#    'model': 'Thunderbird',
#    'needsRepairs': False,
#    'needsCleaning': False},
#   'instanceVersion': 0},
#  {'id': 'fc6896cf-aed4-4357-9814-e680f0993dd8',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-06-13T03:38:51.283Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '886db47e-5a87-4f40-af34-06208598f79e',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'starterUserId': None,
#    'startDate': None,
#    'model': 'Thunderbird',
#    'needsRepairs': False,
#    'needsCleaning': False},
#   'instanceVersion': 0},
#  {'id': '99741914-66c4-4845-b47c-58c32758b049',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-06-13T19:22:57.327Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'b086980c-2273-4cce-83c1-ec67989c8b6a',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 393, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': 'e3c2fcc0-cd4d-4a24-8a7f-efdb8fec57cc',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': None,
#   'startedAt': '2024-06-13T19:25:09.829Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'eb876029-ccff-4186-978c-54a2a7b5ec52',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 2169, 'starterUserId': None, 'startDate': None},
#   'instanceVersion': 0},
#  {'id': 'a307037b-f9b8-4442-94c7-d9a30c48c267',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'wait',
#   'userName': 'John',
#   'startedAt': '2024-06-13T19:39:57.908Z',
#   'endedAt': None,
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': '3b15cb73-427b-472b-91cd-b1455468afaf',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': 'John',
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 9311, 'starterUserId': 'John', 'startDate': None},
#   'instanceVersion': 0},
#  {'id': 'b7479fe7-83a2-4b27-b4f2-add20cabf9ff',
#   'seq': 10,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'task_Drive',
#   'name': 'Drive',
#   'status': 'end',
#   'userName': 'John Kennedy',
#   'startedAt': '2024-06-21T04:33:57.002Z',
#   'endedAt': '2024-06-21T04:33:57.132Z',
#   'type': 'bpmn:UserTask',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'bfce03c4-2c3d-4887-80a6-158fb8a1e186',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': 'John Kennedy',
#   'dueDate': '1970-01-01T00:00:00.000Z',
#   'followUpDate': '1970-01-01T00:00:00.000Z',
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': '7002',
#    'starterUserId': 'John Kennedy',
#    'startDate': '2024-06-21T04:33:53.232Z',
#    'needsRepairs': 'Yes'},
#   'instanceVersion': 0},
#  {'id': '931d3f8f-d448-4488-a33f-7caa2a546026',
#   'seq': 11,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'Flow_0jr762g',
#   'name': None,
#   'status': 'end',
#   'userName': 'system',
#   'startedAt': None,
#   'endedAt': None,
#   'type': 'bpmn:SequenceFlow',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'f2dcd7fb-e98c-44b3-8e38-33029cb72a25',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 9788,
#    'starterUserId': 'system',
#    'startDate': None,
#    'needsRepairs': '',
#    'needsCleaning': ''},
#   'instanceVersion': 0},
#  {'id': '345c1135-367a-4d44-9de8-98c0c0d465be',
#   'seq': 11,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'flow_drive_end',
#   'name': None,
#   'status': 'end',
#   'userName': 'John Kennedy',
#   'startedAt': None,
#   'endedAt': None,
#   'type': 'bpmn:SequenceFlow',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'bfce03c4-2c3d-4887-80a6-158fb8a1e186',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': '7002',
#    'starterUserId': 'John Kennedy',
#    'startDate': '2024-06-21T04:33:53.232Z',
#    'needsRepairs': 'Yes'},
#   'instanceVersion': 0},
#  {'id': '3cfd81ab-7f71-4a93-a9bf-57f0c887d0ec',
#   'seq': 12,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'Event_19ebav7',
#   'name': None,
#   'status': 'end',
#   'userName': 'system',
#   'startedAt': '2024-05-24T03:45:07.454Z',
#   'endedAt': '2024-05-24T03:45:07.466Z',
#   'type': 'bpmn:EndEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'f2dcd7fb-e98c-44b3-8e38-33029cb72a25',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': 9788,
#    'starterUserId': 'system',
#    'startDate': None,
#    'needsRepairs': '',
#    'needsCleaning': ''},
#   'instanceVersion': 0},
#  {'id': '6ed14032-b5d9-46b2-8d40-06781f292dab',
#   'seq': 12,
#   'itemKey': None,
#   'tokenId': 0,
#   'elementId': 'Event_19ebav7',
#   'name': None,
#   'status': 'end',
#   'userName': 'John Kennedy',
#   'startedAt': '2024-06-21T04:33:57.148Z',
#   'endedAt': '2024-06-21T04:33:57.170Z',
#   'type': 'bpmn:EndEvent',
#   'timeDue': None,
#   'vars': {},
#   'instanceId': 'bfce03c4-2c3d-4887-80a6-158fb8a1e186',
#   'messageId': None,
#   'signalId': None,
#   'assignee': None,
#   'candidateGroups': None,
#   'candidateUsers': None,
#   'dueDate': None,
#   'followUpDate': None,
#   'priority': None,
#   'processName': 'Buy Used Car',
#   'data': {'caseId': '7002',
#    'starterUserId': 'John Kennedy',
#    'startDate': '2024-06-21T04:33:53.232Z',
#    'needsRepairs': 'Yes'},
#   'instanceVersion': 0}]
